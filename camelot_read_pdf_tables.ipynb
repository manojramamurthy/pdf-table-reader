# %%
# !pip install camelot-py[cv]
# Out:
# zsh:1: no matches found: camelot-py[cv]

# %%
import camelot

# %%
tables = camelot.read_pdf('sample/FoodCaloriesList.pdf',
    pages='all',
    password=None,
    suppress_stdout=False,
    layout_kwargs={})

# %%
tables.export('output.csv', f='csv', compress=True) # json, excel, html, markdown, sqlite

# %%
tables[0].parsing_report
# Out:
# {'accuracy': 100.0, 'whitespace': 3.57, 'order': 1, 'page': 1}

# %%
tables[0].df
# Out:
#                                                     0  \
# 0   per 100 grams \nBREADS & CEREALS \nPortion siz...
# 1                                 Bagel ( 1 average )
# 2                                  Biscuit digestives
# 3                                          Jaffa cake
# 4                           Bread white (thick slice)
# 5                             Bread wholemeal (thick)
# 6                                            Chapatis
# 7                                          Cornflakes
# 8                                        Crackerbread
# 9                                      Cream crackers
# 10                                           Crumpets
# 11                          Flapjacks basic fruit mix
# 12                                  Macaroni (boiled)
# 13                                             Muesli
# 14                                Naan bread (normal)
# 15                                   Noodles (boiled)
# ...
